# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_squared_error, mean_absolute_error

# load the training and test data
X_train = np.load('xTrain.npy') # training data
X_test = np.load('xTest.npy') # test data
y_train = np.load('yTrain.npy') # target variable for training data

# define the number of folds for cross validation
n_splits = 10 # folds per repeat
n_repeats = 10 # repeats of cross-validation procedure

# define the model
model = RandomForestRegressor(n_estimators=100, random_state=42) # random forest regression model with 100 trees and fixed random state

# initialize the cross-validation object
rkf = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=42)

# initialize lists to store the RMSE and MAE for each repeat
rmse_list = [] # root mean squared error
mae_list = [] # mean absolute error

# initialize an array to store the predictions
y_pred = np.zeros_like(y_train)

# iterate over the folds
for i, (train_index, val_index) in enumerate(rkf.split(X_train)):
    # get the training and validation data for this fold
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index] # split the feature matrix
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index] # split the target variable
        
    # fit the model on the training data for this fold
    model.fit(X_train_fold, y_train_fold)
       
    # make predictions on the validation data for this fold
    y_val_pred = model.predict(X_val_fold)
    
    # store the predictions for this fold in the overall predictions array
    y_pred[val_index] = y_val_pred
    
    # calculate the RMSE and MAE for this fold
    rmse = np.sqrt(mean_squared_error(y_val_fold, y_val_pred))
    mae = mean_absolute_error(y_val_fold, y_val_pred)
    
    # add the RMSE and MAE to the lists
    rmse_list.append(rmse)
    mae_list.append(mae)
    
    # print the RMSE and MAE for this fold
    print(f"Repeat {i//n_splits+1}, Fold {i%n_splits+1} - RMSE: {rmse:.2f}, MAE: {mae:.2f}")

# calculate the mean and standard deviation of the RMSE and MAE across all folds and repeats
mean_rmse = np.mean(rmse_list)
std_rmse = np.std(rmse_list)
mean_mae = np.mean(mae_list)
std_mae = np.std(mae_list)

# print the mean and standard deviation of the RMSE and MAE
print(f"\nMean RMSE: {mean_rmse:.2f} (std: {std_rmse:.2f})")
print(f"Mean MAE: {mean_mae:.2f} (std: {std_mae:.2f})")

# make predictions on the test data using the trained model
y_test_pred = model.predict(X_test)
print(y_test_pred)
np.save('yPred.npy',y_test_pred)
# Out:
# Repeat 1, Fold 1 - RMSE: 15.22, MAE: 10.91
# Repeat 1, Fold 2 - RMSE: 16.56, MAE: 14.12
# Repeat 1, Fold 3 - RMSE: 18.31, MAE: 14.10
# Repeat 1, Fold 4 - RMSE: 16.08, MAE: 12.51
# Repeat 1, Fold 5 - RMSE: 15.20, MAE: 12.47
# Repeat 1, Fold 6 - RMSE: 24.13, MAE: 18.32
# Repeat 1, Fold 7 - RMSE: 19.59, MAE: 16.17
# Repeat 1, Fold 8 - RMSE: 18.93, MAE: 15.66
# Repeat 1, Fold 9 - RMSE: 19.43, MAE: 16.15
# Repeat 1, Fold 10 - RMSE: 15.80, MAE: 12.27
# Repeat 2, Fold 1 - RMSE: 19.54, MAE: 15.38
# Repeat 2, Fold 2 - RMSE: 17.95, MAE: 13.98
# Repeat 2, Fold 3 - RMSE: 17.52, MAE: 14.58
# Repeat 2, Fold 4 - RMSE: 20.55, MAE: 17.62
# Repeat 2, Fold 5 - RMSE: 17.51, MAE: 13.75
# Repeat 2, Fold 6 - RMSE: 15.64, MAE: 10.95
# Repeat 2, Fold 7 - RMSE: 22.18, MAE: 15.87
# Repeat 2, Fold 8 - RMSE: 16.30, MAE: 13.42
# Repeat 2, Fold 9 - RMSE: 18.58, MAE: 15.09
# Repeat 2, Fold 10 - RMSE: 16.82, MAE: 13.20
# Repeat 3, Fold 1 - RMSE: 15.82, MAE: 13.42
# Repeat 3, Fold 2 - RMSE: 21.90, MAE: 17.85
# Repeat 3, Fold 3 - RMSE: 15.62, MAE: 12.56
# Repeat 3, Fold 4 - RMSE: 20.81, MAE: 14.86
# Repeat 3, Fold 5 - RMSE: 15.59, MAE: 11.69
# Repeat 3, Fold 6 - RMSE: 13.97, MAE: 11.33
# Repeat 3, Fold 7 - RMSE: 21.16, MAE: 18.10
# Repeat 3, Fold 8 - RMSE: 21.11, MAE: 14.61
# Repeat 3, Fold 9 - RMSE: 16.99, MAE: 13.27
# Repeat 3, Fold 10 - RMSE: 17.60, MAE: 14.72
# Repeat 4, Fold 1 - RMSE: 15.08, MAE: 12.77
# Repeat 4, Fold 2 - RMSE: 17.26, MAE: 14.40
# Repeat 4, Fold 3 - RMSE: 14.96, MAE: 12.13
# Repeat 4, Fold 4 - RMSE: 18.41, MAE: 14.68
# Repeat 4, Fold 5 - RMSE: 19.55, MAE: 16.79
# Repeat 4, Fold 6 - RMSE: 17.61, MAE: 14.27
# Repeat 4, Fold 7 - RMSE: 12.40, MAE: 9.03
# Repeat 4, Fold 8 - RMSE: 17.06, MAE: 12.85
# Repeat 4, Fold 9 - RMSE: 21.21, MAE: 16.47
# Repeat 4, Fold 10 - RMSE: 24.63, MAE: 17.91
# Repeat 5, Fold 1 - RMSE: 19.11, MAE: 15.15
# Repeat 5, Fold 2 - RMSE: 19.99, MAE: 16.04
# Repeat 5, Fold 3 - RMSE: 15.88, MAE: 11.44
# Repeat 5, Fold 4 - RMSE: 15.35, MAE: 11.41
# Repeat 5, Fold 5 - RMSE: 18.55, MAE: 15.97
# Repeat 5, Fold 6 - RMSE: 25.26, MAE: 19.75
# Repeat 5, Fold 7 - RMSE: 17.70, MAE: 13.47
# Repeat 5, Fold 8 - RMSE: 13.75, MAE: 11.61
# Repeat 5, Fold 9 - RMSE: 18.13, MAE: 13.75
# Repeat 5, Fold 10 - RMSE: 15.69, MAE: 12.16
# Repeat 6, Fold 1 - RMSE: 17.22, MAE: 14.20
# Repeat 6, Fold 2 - RMSE: 17.59, MAE: 14.77
# Repeat 6, Fold 3 - RMSE: 13.57, MAE: 11.45
# Repeat 6, Fold 4 - RMSE: 15.60, MAE: 12.37
# Repeat 6, Fold 5 - RMSE: 16.41, MAE: 11.56
# Repeat 6, Fold 6 - RMSE: 17.61, MAE: 13.71
# Repeat 6, Fold 7 - RMSE: 17.71, MAE: 13.89
# Repeat 6, Fold 8 - RMSE: 19.47, MAE: 15.31
# Repeat 6, Fold 9 - RMSE: 21.13, MAE: 13.51
# Repeat 6, Fold 10 - RMSE: 18.06, MAE: 14.83
# Repeat 7, Fold 1 - RMSE: 14.81, MAE: 11.98
# Repeat 7, Fold 2 - RMSE: 18.77, MAE: 14.31
# Repeat 7, Fold 3 - RMSE: 17.62, MAE: 14.19
# Repeat 7, Fold 4 - RMSE: 21.51, MAE: 17.75
# Repeat 7, Fold 5 - RMSE: 18.82, MAE: 13.12
# Repeat 7, Fold 6 - RMSE: 20.55, MAE: 17.08
# Repeat 7, Fold 7 - RMSE: 15.39, MAE: 11.64
# Repeat 7, Fold 8 - RMSE: 16.31, MAE: 12.65
# Repeat 7, Fold 9 - RMSE: 16.47, MAE: 13.70
# Repeat 7, Fold 10 - RMSE: 16.65, MAE: 13.67
# Repeat 8, Fold 1 - RMSE: 15.79, MAE: 10.89
# Repeat 8, Fold 2 - RMSE: 16.28, MAE: 13.57
# Repeat 8, Fold 3 - RMSE: 18.39, MAE: 12.60
# Repeat 8, Fold 4 - RMSE: 17.69, MAE: 14.91
# Repeat 8, Fold 5 - RMSE: 16.82, MAE: 12.39
# Repeat 8, Fold 6 - RMSE: 12.94, MAE: 9.91
# Repeat 8, Fold 7 - RMSE: 19.15, MAE: 15.46
# Repeat 8, Fold 8 - RMSE: 14.63, MAE: 12.35
# Repeat 8, Fold 9 - RMSE: 23.78, MAE: 19.26
# Repeat 8, Fold 10 - RMSE: 15.38, MAE: 12.38
# Repeat 9, Fold 1 - RMSE: 13.80, MAE: 10.41
# Repeat 9, Fold 2 - RMSE: 18.08, MAE: 16.43
# Repeat 9, Fold 3 - RMSE: 19.19, MAE: 14.61
# Repeat 9, Fold 4 - RMSE: 18.37, MAE: 14.35
# Repeat 9, Fold 5 - RMSE: 16.98, MAE: 13.38
# Repeat 9, Fold 6 - RMSE: 20.05, MAE: 15.54
# Repeat 9, Fold 7 - RMSE: 21.32, MAE: 17.10
# Repeat 9, Fold 8 - RMSE: 20.21, MAE: 13.21
# Repeat 9, Fold 9 - RMSE: 14.72, MAE: 9.76
# Repeat 9, Fold 10 - RMSE: 19.05, MAE: 15.42
# Repeat 10, Fold 1 - RMSE: 17.41, MAE: 14.41
# Repeat 10, Fold 2 - RMSE: 16.06, MAE: 12.49
# Repeat 10, Fold 3 - RMSE: 21.08, MAE: 15.69
# Repeat 10, Fold 4 - RMSE: 14.23, MAE: 11.08
# Repeat 10, Fold 5 - RMSE: 23.93, MAE: 19.16
# Repeat 10, Fold 6 - RMSE: 16.79, MAE: 14.01
# Repeat 10, Fold 7 - RMSE: 14.53, MAE: 9.35
# Repeat 10, Fold 8 - RMSE: 16.34, MAE: 13.19
# Repeat 10, Fold 9 - RMSE: 17.72, MAE: 13.33
# Repeat 10, Fold 10 - RMSE: 16.31, MAE: 12.81
#
# Mean RMSE: 17.78 (std: 2.62)
# Mean MAE: 13.96 (std: 2.22)
# [127.06259304 134.29641693 141.47378871 127.20384565 153.75856244
#  134.47909719 140.98475993 139.16689335 133.91156208 146.72506343
#  142.56064021 150.36866968 133.34316573 146.23760503 138.27475766
#  153.64309697 151.0494244  142.90723062 144.73716015 153.21867084
#  133.38317085 141.314092   135.70511312 117.70084124 139.52163686
#  133.75752502 149.27541076 135.85648078 146.76453706 133.41577298
#  142.22290567 137.20976123 137.84901458 135.84015448 132.75487555
#  157.43103537 146.16443891 144.45091214 131.47074398 151.04314818
#  128.28232362 133.10461132 136.4532951  128.59192252 121.70887654
#  132.91293798 136.14361043 145.48956081 132.1884545  138.36909521
#  140.33441591 142.15478284]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 67
#      65 y_test_pred = model.predict(X_test)
#      66 print(y_test_pred)
# ---> 67 save('yPred.npy',y_test_pred)
#
# NameError: name 'save' is not defined

# %%
np.save('yPred.npy',y_test_pred)
